# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading data

# %%
data = pd.read_csv("C:\\Users\\abhil\\Desktop\\ML Codes\\housing.csv")

# %%
data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %% [markdown]
# ## Scaling data with MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
#it has string values and we want catgorical data
#we need to preprocess teh data
scaler.fit(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33056/580861187.py in <module>
#       1 #it has string values and we want catgorical data
#       2 #we need to preprocess teh data
# ----> 3 scaler.fit(data)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     394
#     395         first_pass = not hasattr(self, 'n_samples_seen_')
# --> 396         X = self._validate_data(X, reset=first_pass,
#     397                                 estimator=self, dtype=FLOAT_DTYPES,
# ...

# %% [markdown]
# #### Data Processing

# %% [markdown]
# ##### a.dropping categorical data columns
# ##### b.dropping rows with null values

# %% [markdown]
# ##### Note : these steps are performed to show the scaling part only

# %%
data = data.drop(data.columns[[9]], axis = 1)

# %%
data = data.dropna(axis = 0)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# ...

# %% [markdown]
# ### Scaling part

# %%
scaler = MinMaxScaler()
scaler.fit(data)
# Out:
# MinMaxScaler()

# %%
scaled_data = pd.DataFrame(data = scaler.transform(data), columns = data.columns, index = data.index)

# %%
scaled_data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0   0.211155  0.567481            0.784314     0.022331        0.019863
# 1   0.212151  0.565356            0.392157     0.180503        0.171477
# 2   0.210159  0.564293            1.000000     0.037260        0.029330
# 3   0.209163  0.564293            1.000000     0.032352        0.036313
# 4   0.209163  0.564293            1.000000     0.041330        0.043296
# 5   0.209163  0.564293            1.000000     0.023323        0.032899
# 6   0.209163  0.563231            1.000000     0.064423        0.075729
# 7   0.209163  0.563231            1.000000     0.078895        0.106456
# 8   0.208167  0.563231            0.803922     0.064932        0.103042
# 9   0.209163  0.563231            1.000000     0.090213        0.109559
#
#    population  households  median_income  median_house_value
# 0    0.008941    0.020556       0.539668            0.902266
# ...
